# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MSFT_stock_prediction/MSFT_stock_data.csv')
df.head(5)
# Out:
#         Price                Close                 High                  Low  \
# 0      Ticker                 MSFT                 MSFT                 MSFT
# 1        Date                  NaN                  NaN                  NaN
# 2  1987-01-02  0.10202644020318985  0.10416297795428771  0.10149230118060978
# 3  1987-01-05   0.1079019233584404  0.10897019232234555  0.10149230957500951
# 4  1987-01-06   0.1095043271780014  0.11003846626894652  0.10736778915344568
#
#                   Open    Volume
# 0                 MSFT      MSFT
# 1                  NaN       NaN
# 2  0.10309470907873877  12643200
# 3  0.10202644864176807  48499200
# 4   0.1079019282443908  40032000

# %%
df = df.iloc[2:]
df
# Out:
#            Price                Close                 High  \
# 2     1987-01-02  0.10202644020318985  0.10416297795428771
# 3     1987-01-05   0.1079019233584404  0.10897019232234555
# 4     1987-01-06   0.1095043271780014  0.11003846626894652
# 5     1987-01-07  0.11538039892911911  0.11538039892911911
# 6     1987-01-08   0.1191193163394928  0.12018820846983241
# ...          ...                  ...                  ...
# 9602  2025-02-10    412.2200012207031    415.4599914550781
# 9603  2025-02-11   411.44000244140625     412.489990234375
# 9604  2025-02-12    409.0400085449219               410.75
# 9605  2025-02-13    410.5400085449219                411.0
# 9606  2025-02-14   408.42999267578125    408.9100036621094
#
#                       Low                 Open    Volume
# 2     0.10149230118060978  0.10309470907873877  12643200
# 3     0.10149230957500951  0.10202644864176807  48499200
# 4     0.10736778915344568   0.1079019282443908  40032000
# 5     0.10950430177585643  0.10950430177585643  60998400
# 6     0.11591451054867286  0.11591451054867286  61488000
# ...                   ...                  ...       ...
# 9602    410.9200134277344    413.7099914550781  20817900
# 9603   409.29998779296875    409.6400146484375  18140600
# 9604    404.3699951171875    407.2099914550781  19121700
# 9605    406.3599853515625                407.0  23891700
# 9606    405.8800048828125    407.7900085449219  22758500
#
# [9605 rows x 6 columns]

# %%
df.rename(columns={'Price':'Date'}, inplace=True)
df
# Out:
#             Date                Close                 High  \
# 2     1987-01-02  0.10202644020318985  0.10416297795428771
# 3     1987-01-05   0.1079019233584404  0.10897019232234555
# 4     1987-01-06   0.1095043271780014  0.11003846626894652
# 5     1987-01-07  0.11538039892911911  0.11538039892911911
# 6     1987-01-08   0.1191193163394928  0.12018820846983241
# ...          ...                  ...                  ...
# 9602  2025-02-10    412.2200012207031    415.4599914550781
# 9603  2025-02-11   411.44000244140625     412.489990234375
# 9604  2025-02-12    409.0400085449219               410.75
# 9605  2025-02-13    410.5400085449219                411.0
# 9606  2025-02-14   408.42999267578125    408.9100036621094
#
#                       Low                 Open    Volume
# 2     0.10149230118060978  0.10309470907873877  12643200
# 3     0.10149230957500951  0.10202644864176807  48499200
# 4     0.10736778915344568   0.1079019282443908  40032000
# 5     0.10950430177585643  0.10950430177585643  60998400
# 6     0.11591451054867286  0.11591451054867286  61488000
# ...                   ...                  ...       ...
# 9602    410.9200134277344    413.7099914550781  20817900
# 9603   409.29998779296875    409.6400146484375  18140600
# 9604    404.3699951171875    407.2099914550781  19121700
# 9605    406.3599853515625                407.0  23891700
# 9606    405.8800048828125    407.7900085449219  22758500
#
# [9605 rows x 6 columns]

# %%
df['Date']
# Out:
# 2       1987-01-02
# 3       1987-01-05
# 4       1987-01-06
# 5       1987-01-07
# 6       1987-01-08
#            ...
# 9602    2025-02-10
# 9603    2025-02-11
# 9604    2025-02-12
# 9605    2025-02-13
# 9606    2025-02-14
# Name: Date, Length: 9605, dtype: object

# %%
# converting the datatype of 'Date' from string to datetime
import datetime
def str_to_date(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

# %%
df['Date'] = df['Date'].apply(str_to_date)
df
# Out:
#            Date                Close                 High  \
# 2    1987-01-02  0.10202644020318985  0.10416297795428771
# 3    1987-01-05   0.1079019233584404  0.10897019232234555
# 4    1987-01-06   0.1095043271780014  0.11003846626894652
# 5    1987-01-07  0.11538039892911911  0.11538039892911911
# 6    1987-01-08   0.1191193163394928  0.12018820846983241
# ...         ...                  ...                  ...
# 9602 2025-02-10    412.2200012207031    415.4599914550781
# 9603 2025-02-11   411.44000244140625     412.489990234375
# 9604 2025-02-12    409.0400085449219               410.75
# 9605 2025-02-13    410.5400085449219                411.0
# 9606 2025-02-14   408.42999267578125    408.9100036621094
#
#                       Low                 Open    Volume
# 2     0.10149230118060978  0.10309470907873877  12643200
# 3     0.10149230957500951  0.10202644864176807  48499200
# 4     0.10736778915344568   0.1079019282443908  40032000
# 5     0.10950430177585643  0.10950430177585643  60998400
# 6     0.11591451054867286  0.11591451054867286  61488000
# ...                   ...                  ...       ...
# 9602    410.9200134277344    413.7099914550781  20817900
# 9603   409.29998779296875    409.6400146484375  18140600
# 9604    404.3699951171875    407.2099914550781  19121700
# 9605    406.3599853515625                407.0  23891700
# 9606    405.8800048828125    407.7900085449219  22758500
#
# [9605 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9605 entries, 2 to 9606
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9605 non-null   datetime64[ns]
#  1   Close   9605 non-null   object
#  2   High    9605 non-null   object
#  3   Low     9605 non-null   object
#  4   Open    9605 non-null   object
#  5   Volume  9605 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 450.4+ KB

# %%
# changing the datatype of all other columns from object to float
for col in ['Open', 'Close', 'High', 'Low', 'Volume']:
    df[col] = df[col].astype(float)

# %%
# removing the 'Date' column and use it as index
df.index = df.pop('Date')
df
# Out:
#                  Close        High         Low        Open      Volume
# Date
# 1987-01-02    0.102026    0.104163    0.101492    0.103095  12643200.0
# 1987-01-05    0.107902    0.108970    0.101492    0.102026  48499200.0
# 1987-01-06    0.109504    0.110038    0.107368    0.107902  40032000.0
# 1987-01-07    0.115380    0.115380    0.109504    0.109504  60998400.0
# 1987-01-08    0.119119    0.120188    0.115915    0.115915  61488000.0
# ...                ...         ...         ...         ...         ...
# 2025-02-10  412.220001  415.459991  410.920013  413.709991  20817900.0
# 2025-02-11  411.440002  412.489990  409.299988  409.640015  18140600.0
# 2025-02-12  409.040009  410.750000  404.369995  407.209991  19121700.0
# 2025-02-13  410.540009  411.000000  406.359985  407.000000  23891700.0
# 2025-02-14  408.429993  408.910004  405.880005  407.790009  22758500.0
#
# [9605 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9605 entries, 1987-01-02 to 2025-02-14
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   9605 non-null   float64
#  1   High    9605 non-null   float64
#  2   Low     9605 non-null   float64
#  3   Open    9605 non-null   float64
#  4   Volume  9605 non-null   float64
# dtypes: float64(5)
# memory usage: 450.2 KB

# %%
# plotting line graph of closing price
df.plot.line(y='Close', use_index=True, title='MSFT Stock Price');

# %%
# creating a new column for tomorrow's price
df['Tomorrow'] = df['Close'].shift(-1)
df
# Out:
#                  Close        High         Low        Open      Volume  \
# Date
# 1987-01-02    0.102026    0.104163    0.101492    0.103095  12643200.0
# 1987-01-05    0.107902    0.108970    0.101492    0.102026  48499200.0
# 1987-01-06    0.109504    0.110038    0.107368    0.107902  40032000.0
# 1987-01-07    0.115380    0.115380    0.109504    0.109504  60998400.0
# 1987-01-08    0.119119    0.120188    0.115915    0.115915  61488000.0
# ...                ...         ...         ...         ...         ...
# 2025-02-10  412.220001  415.459991  410.920013  413.709991  20817900.0
# 2025-02-11  411.440002  412.489990  409.299988  409.640015  18140600.0
# 2025-02-12  409.040009  410.750000  404.369995  407.209991  19121700.0
# 2025-02-13  410.540009  411.000000  406.359985  407.000000  23891700.0
# 2025-02-14  408.429993  408.910004  405.880005  407.790009  22758500.0
#
#               Tomorrow
# Date
# 1987-01-02    0.107902
# 1987-01-05    0.109504
# 1987-01-06    0.115380
# 1987-01-07    0.119119
# 1987-01-08    0.123927
# ...                ...
# 2025-02-10  411.440002
# 2025-02-11  409.040009
# 2025-02-12  410.540009
# 2025-02-13  408.429993
# 2025-02-14         NaN
#
# [9605 rows x 6 columns]

# %%
# creating a new column 'Target' for predicting stock direction & also convert it to int
df["Target"] = (df['Tomorrow'] > df['Close']).astype(int)

# %%
# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)
train =df.iloc[:-100]
test = df.iloc[-100:]

predictors = ['Close', 'High', 'Low', 'Open', 'Volume']
model.fit(train[predictors], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)

# %%
preds
# Out:
# Date
# 2024-09-23    1
# 2024-09-24    0
# 2024-09-25    1
# 2024-09-26    1
# 2024-09-27    1
#              ..
# 2025-02-10    1
# 2025-02-11    1
# 2025-02-12    0
# 2025-02-13    0
# 2025-02-14    0
# Length: 100, dtype: int64

# %%
precision_score(test['Target'], preds)
# Out:
# 0.4827586206896552

# %%
# concatinating 'Target' with predictions
combined = pd.concat([ test['Target'], preds ], axis=1)
combined.plot();

# %%
# backtesting
def predict(train, test, predictors, model):
  model.fit(train[predictors], train['Target'])
  preds = model.predict(test[predictors])
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test['Target'], preds], axis=1)
  return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
	all_predictions = []

	for i in range(start, data.shape[0], step):
		train = data.iloc[0:i].copy()
		test = data.iloc[i:(i+step)].copy()
		predictions = predict(train, test, predictors, model)
		all_predictions.append(predictions)
	return pd.concat(all_predictions)

# %%
predictions = backtest(df, model, predictors)

# %%
predictions
# Out:
#             Target  Predictions
# Date
# 1996-11-19       0            1
# 1996-11-20       0            1
# 1996-11-21       1            1
# 1996-11-22       1            1
# 1996-11-25       1            1
# ...            ...          ...
# 2025-02-10       0            1
# 2025-02-11       0            1
# 2025-02-12       1            1
# 2025-02-13       0            1
# 2025-02-14       0            0
#
# [7105 rows x 2 columns]

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    4612
# 1    2493
# Name: count, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.5098275170477337

# %%
predictions['Target'].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.510626
# 0    0.489374
# Name: count, dtype: float64

# %%
horizons =[2,5,6,250,100]
new_predictors =[]

for horizon in horizons:
  rolling_averages = df.rolling(horizon).mean()

  ratio_column = f"Close_Ratio_{horizon}"
  df[ratio_column] = df["Close"] / rolling_averages['Close']

  trend_column = f"Trend_{horizon}"
  df[trend_column] = df.shift(1).rolling(horizon).sum()['Target']

  new_predictors += [ratio_column, trend_column]

# %%
df.dropna(inplace=True) # dropping no Data rows

# %%
df
# Out:
#                  Close        High         Low        Open      Volume  \
# Date
# 1988-12-21    0.223282    0.224351    0.219009    0.220077  46440000.0
# 1988-12-22    0.222214    0.226488    0.221146    0.224351  74592000.0
# 1988-12-23    0.222214    0.222214    0.220077    0.221146  17121600.0
# 1988-12-27    0.221146    0.224351    0.221146    0.222214  30772800.0
# 1988-12-28    0.223282    0.223282    0.221146    0.222214  21268800.0
# ...                ...         ...         ...         ...         ...
# 2025-02-07  409.750000  418.649994  408.100006  416.480011  22886800.0
# 2025-02-10  412.220001  415.459991  410.920013  413.709991  20817900.0
# 2025-02-11  411.440002  412.489990  409.299988  409.640015  18140600.0
# 2025-02-12  409.040009  410.750000  404.369995  407.209991  19121700.0
# 2025-02-13  410.540009  411.000000  406.359985  407.000000  23891700.0
#
#               Tomorrow  Target  Close_Ratio_2  Close_Ratio_5  Close_Ratio_6  \
# Date
# 1988-12-21    0.222214       0       1.009661       1.032608       1.040231
# 1988-12-22    0.222214       0       0.997602       1.015624       1.022950
# 1988-12-23    0.221146       0       1.000000       1.006776       1.012987
# 1988-12-27    0.223282       1       0.997591       0.998072       1.001613
# 1988-12-28    0.227556       1       1.004807       1.003842       1.006420
# ...                ...     ...            ...            ...            ...
# 2025-02-07  412.220001       1       0.992647       0.993502       0.992447
# 2025-02-10  411.440002       0       1.003005       0.998861       0.999576
# 2025-02-11  409.040009       0       0.999053       0.997421       0.997475
# 2025-02-12  410.540009       1       0.997075       0.993650       0.992992
# 2025-02-13  408.429993       0       1.001830       0.999859       0.997744
#
#             Close_Ratio_250  Close_Ratio_100  Trend_2  Trend_5  Trend_6  \
# Date
# 1988-12-21         0.940306         1.033604      2.0      5.0      6.0
# 1988-12-22         0.935975         1.029779      1.0      4.0      5.0
# 1988-12-23         0.936228         1.030646      0.0      3.0      4.0
# 1988-12-27         0.931895         1.026455      0.0      2.0      3.0
# 1988-12-28         0.941152         1.036628      1.0      2.0      3.0
# ...                     ...              ...      ...      ...      ...
# 2025-02-07         0.970050         0.961718      1.0      3.0      4.0
# 2025-02-10         0.975946         0.967930      1.0      4.0      4.0
# 2025-02-11         0.974106         0.966617      1.0      3.0      4.0
# 2025-02-12         0.968371         0.961451      0.0      2.0      3.0
# 2025-02-13         0.971892         0.965596      1.0      2.0      3.0
#
#             Trend_250  Trend_100
# Date
# 1988-12-21      120.0       42.0
# 1988-12-22      119.0       42.0
# 1988-12-23      118.0       42.0
# 1988-12-27      118.0       42.0
# 1988-12-28      118.0       43.0
# ...               ...        ...
# 2025-02-07      131.0       53.0
# 2025-02-10      131.0       53.0
# 2025-02-11      131.0       52.0
# 2025-02-12      131.0       52.0
# 2025-02-13      131.0       52.0
#
# [9105 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
# adding predict probability
def predict(train, test, predictors, model):
  model.fit(train[predictors], train['Target'])
  preds = model.predict_proba(test[predictors])[:,1]
  preds[preds >= .6] = 1
  preds[preds < .6] = 0
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test['Target'], preds], axis=1)
  return combined

# %%
predictions = backtest(df, model, new_predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0.0    6127
# 1.0     478
# Name: count, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.5376569037656904

# %%
df = combined.drop(df.columns[0], axis=1)  # Removes the first Target column (index 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-408-f95a46b3e7a8> in <cell line: 0>()
# ----> 1 df = combined.drop(df.columns[0], axis=1)  # Removes the first Target column (index 1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4857                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4858                 if errors == "raise" and labels_missing:
# -> 4859                     raise KeyError(f"{labels} not found in axis")
#    4860
#    4861             if isinstance(mask.dtype, ExtensionDtype):
#
# KeyError: "['Close'] not found in axis"
