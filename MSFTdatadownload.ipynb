# %%
import yfinance as yf

# Define the ticker symbol
ticker_symbol = 'MSFT'

# Get data from Yahoo Finance
stock_data = yf.download(ticker_symbol, start='1987-01-01', end='2025-02-18')

# Display the first few rows
print(stock_data.head())

# Save to CSV
stock_data.to_csv('MSFT_stock_data.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MSFT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, MSFT), (Close, MSFT), (High, MSFT), (Low, MSFT), (Open, MSFT), (Volume, MSFT)]
# Index: []

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('MSFT_stock_data.csv')
df
# Out:
#     Price Adj Close Close  High   Low  Open Volume
# 0  Ticker      MSFT  MSFT  MSFT  MSFT  MSFT   MSFT
# 1    Date       NaN   NaN   NaN   NaN   NaN    NaN

# %%
df = df.iloc[2:]
df
# Out:
# Empty DataFrame
# Columns: [Price, Adj Close, Close, High, Low, Open, Volume]
# Index: []

# %%
df.rename(columns={'Price':'Date'}, inplace=True)
df
# Out:
# <ipython-input-16-c9360ddae91c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Price':'Date'}, inplace=True)
# Empty DataFrame
# Columns: [Date, Adj Close, Close, High, Low, Open, Volume]
# Index: []

# %%
df['Date']
# Out:
# Series([], Name: Date, dtype: object)
